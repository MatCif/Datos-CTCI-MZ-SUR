# %%
#Se importan librerías importantes para el manejo de matrices
import numpy as np
import pandas as pd

# pandas y seaborn trabajan sobre matplotlib, una biblioteca de bajo nivel.
# el submódulo pyplot contiene métodos que nos permitirán manipular los gráficos.
import matplotlib.pyplot as plt


df = pd.read_csv("https://www.mifuturo.cl/wp-content/uploads/2022/07/OFICIAL_WEB_PROCESO_MAT_2007_AL_2022_24_06_2022_E-1.zip",compression="zip")

# %%
import requests, zipfile, io

url = 'https://www.mifuturo.cl/wp-content/uploads/2022/07/OFICIAL_WEB_PROCESO_MAT_2007_AL_2022_24_06_2022_E-1.zip'
filename = 'OFICIAL_WEB_PROCESO_MAT_2007_AL_2022_24_06_2022_E.csv'

r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

import pandas as pd
df = pd.read_csv(filename, sep=';')
df
# Out:
# c:\Users\mcifuentes\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              A�O  TOTAL MATRICULADOS  MATRICULADOS MUJERES POR PROGRAMA  \
# 0       MAT_2022                   2                                2.0
# 1       MAT_2022                  10                                8.0
# 2       MAT_2022                  34                                NaN
# 3       MAT_2022                  10                                NaN
# 4       MAT_2022                  76                                4.0
# ...          ...                 ...                                ...
# 216148  MAT_2007                  18                               13.0
# 216149  MAT_2007                  13                                7.0
# 216150  MAT_2007                  16                               10.0
# ...
