# %% [markdown]
# ##Script para la obtención de datos para el análisis del ecosistema de Ciencia, Tecnología, Conocimiento e Innovación (CTCI)

# %% [markdown]
# El objetivo del siguiente script es consolidar y automatizar la obtención de datos necesarios para la toma de decisiones en política pública con base científica.
# Para lo anterior el presente proyecto se enmarca en dos grandes temas, el primero son en términos de recursos aportado por el uso de instrumentos MinCiencia y el segundo es información aportada por los stakeholders en temática CTCI 🧑.
#
# Fuente:
#
# *   https://observa.minciencia.gob.cl/programas-publicos/instrumentos
# *   https://observa.minciencia.gob.cl/sistema

# %%
#Se importan las librerías importantes
import os
import numpy as np
import pandas as pd
import requests, zipfile, io
# el submódulo pyplot contiene métodos que nos permitirán manipular los gráficos.
import matplotlib.pyplot as plt

# %% [markdown]
# ##Sistema de Información de Educación Superior (SIES)

# %% [markdown]
# de aquí extraeremos:
#
# *   Matrículas
# *   Oferta Académica
# *   Dotación de académicos

# %% [markdown]
# Lo primero que se realiza es la obtención de datos de la página del Sistema de Información de Educación Superior (SIES) en matrículas históricas:

# %%
url = 'https://www.mifuturo.cl/wp-content/uploads/2022/07/OFICIAL_WEB_PROCESO_MAT_2007_AL_2022_24_06_2022_E-1.zip'
filename = 'OFICIAL_WEB_PROCESO_MAT_2007_AL_2022_24_06_2022_E.csv'
r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

df = pd.read_csv(filename, sep=';', encoding='latin-1')

df.dtype={'año': str,'TOTAL MATRICULADOS':int,'MATRICULADOS MUJERES POR PROGRAMA':int}


#Eliminamos el archivo para evitar ambiguedades

os.remove(r'C:\Users\mcifuentes\Google Drive\BBDD General\GitHub\Datos-CTCI-MZ-SUR\src\OFICIAL_WEB_PROCESO_MAT_2007_AL_2022_24_06_2022_E.csv')

df
# Out:
# c:\Users\mcifuentes\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-30-011b56f72d1b>:9: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.dtype={'año': str,'TOTAL MATRICULADOS':int,'MATRICULADOS MUJERES POR PROGRAMA':int}
#              AÑO  TOTAL MATRICULADOS  MATRICULADOS MUJERES POR PROGRAMA  \
# 0       MAT_2022                   2                                2.0
# 1       MAT_2022                  10                                8.0
# 2       MAT_2022                  34                                NaN
# 3       MAT_2022                  10                                NaN
# 4       MAT_2022                  76                                4.0
# ...

# %%
#import os

#absolute_path = os.path.dirname(__file__)
#relative_path = "src/lib"
#full_path = os.path.join(absolute_path, relative_path)

# %% [markdown]
# Para las titulaciones

# %%
url = 'https://www.mifuturo.cl/wp-content/uploads/2022/06/TITULADOS_WEB_2007-2021_22-06-2022_E.zip'
filename = 'TITULADOS_WEB_2007-2021_22-06-2022_E.csv'
r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()
df2 = pd.read_csv(filename, sep=';', encoding='latin-1')
#Eliminamos el archivo para evitar ambiguedades
os.remove(r'C:\Users\mcifuentes\Google Drive\BBDD General\GitHub\Datos-CTCI-MZ-SUR\src\TITULADOS_WEB_2007-2021_22-06-2022_E.csv')
df2
# Out:
#              AÑO  TOTAL TITULADOS  TITULADOS MUJERES POR PROGRAMA  \
# 0       TIT_2021                3                             NaN
# 1       TIT_2021               14                             7.0
# 2       TIT_2021               10                             1.0
# 3       TIT_2021                1                             NaN
# 4       TIT_2021               17                             NaN
# ...          ...              ...                             ...
# 172762  TIT_2007                1                             NaN
# 172763  TIT_2007               11                            11.0
# 172764  TIT_2007               12                             NaN
# 172765  TIT_2007               12                             NaN
# 172766  TIT_2007                4                             2.0
#
#         TITULADOS HOMBRES POR PROGRAMA CLASIFICACIÓN INSTITUCIÓN NIVEL 1  \
# 0                                  3.0          Institutos Profesionales
# ...

# %% [markdown]
# Limpieza de datos SIES

# %%
df.set_axis(['AÑO','TOTAL MATRICULADOS', 'MATRICULADOS MUJERES POR PROGRAMA', 'MATRICULADOS HOMBRES POR PROGRAMA', 'TOTAL MATRICULADOS PRIMER AÑO','MATRICULADOS MUJERES PRIMER AÑO', 'MATRICULADOS HOMBRES PRIMER AÑO',\
            'CLASIFICACIÓN INSTITUCIÓN NIVEL 1', 'CLASIFICACIÓN INSTITUCIÓN NIVEL 2', 'CLASIFICACIÓN INSTITUCIÓN NIVEL 3', 'CÓDIGO DE INSTITUCIÓN', 'NOMBRE INSTITUCIÓN', 'ACREDITACIÓN INSTITUCIONAL', 'REGIÓN',\
            'PROVINCIA','COMUNA', 'NOMBRE SEDE','NOMBRE CARRERA', 'ÁREA DEL CONOCIMIENTO','CINE-F 1997 ÁREA', 'CINE-F 1997 SUBAREA','ÁREA CARRERA GENÉRICA', 'CINE-F 2013 ÁREA','CINE-F 2013 SUBAREA',\
            'NIVEL GLOBAL','CARRERA CLASIFICACIÓN NIVEL 1','CARRERA CLASIFICACIÓN NIVEL 2','MODALIDAD','JORNADA','TIPO DE PLAN DE LA CARRERA', 'DURACIÓN ESTUDIO CARRERA', 'DURACIÓN TOTAL DE CARRERA',\
            'CÓDIGO CARRERA', 'ACREDITACIÓN CARRERA', 'TOTAL RANGO DE EDAD','RANGO DE EDAD 15 A 19 AÑOS', 'RANGO DE EDAD 20 A 24 AÑOS','RANGO DE EDAD 25 A 29 AÑOS', 'RANGO DE EDAD 30 A 34 AÑOS',\
            'RANGO DE EDAD 35 A 39 AÑOS','RANGO DE EDAD 40 Y MÁS AÑOS','RANGO DE EDAD SIN INFORMACIÓN', 'PROMEDIO EDAD CARRERA', 'PROMEDIO EDAD MUJER', 'PROMEDIO EDAD HOMBRE', 'TES MUNICIPAL',\
            'TES PARTICULAR SUBVENCIONADO', 'TES PARTICULAR PAGADO', 'TES CORP. DE ADMINISTRACIÓN DELEGADA', 'TES SERVICIO LOCAL EDUCACION', 'TOTAL TES','% COBERTURA TES', 'TIPO ESTABLECIMIENTO HC',\
            'TIPO ESTABLECIMIENTO TP','CLAS_EST ADULTO', 'CLAS_EST JOVEN'],axis=1,inplace=True)


#Cambiar de string a integer año
df2=df['AÑO'].replace({'MAT_':''},regex=True)

#df = df.astype({'col1': 'object', 'col2': 'int'})



df['AÑO']=df2.astype(int)
df.dtypes
# Out:
# AÑO                                       int32
# TOTAL MATRICULADOS                        int64
# MATRICULADOS MUJERES POR PROGRAMA       float64
# MATRICULADOS HOMBRES POR PROGRAMA       float64
# TOTAL MATRICULADOS PRIMER AÑO           float64
# MATRICULADOS MUJERES PRIMER AÑO         float64
# MATRICULADOS HOMBRES PRIMER AÑO         float64
# CLASIFICACIÓN INSTITUCIÓN NIVEL 1        object
# CLASIFICACIÓN INSTITUCIÓN NIVEL 2        object
# CLASIFICACIÓN INSTITUCIÓN NIVEL 3        object
# CÓDIGO DE INSTITUCIÓN                     int64
# NOMBRE INSTITUCIÓN                       object
# ACREDITACIÓN INSTITUCIONAL               object
# REGIÓN                                   object
# PROVINCIA                                object
# COMUNA                                   object
# NOMBRE SEDE                              object
# NOMBRE CARRERA                           object
# ÁREA DEL CONOCIMIENTO                    object
# CINE-F 1997 ÁREA                         object
# ...

# %% [markdown]
# Se extrae la información

# %% [markdown]
# Lo segundo consiste en

# %%
#import requests
#from bs4 import BeautifulSoup
 
 
#url = 'https://www.mifuturo.cl/bases-de-datos-de-matriculados/'
#reqs = requests.get(url)
#soup = BeautifulSoup(reqs.text, 'html.parser')
 
#urls = []
#for link in soup.find_all('a'):
#    print(link.get('href'))

# %% [markdown]
# ##Agencia Nacional de Investigación (ANID)
# de aquí extraeremos:
#
#
#
# *   Proyectos ANID Financiados
# *   Becas Adjudicadas

# %%
#Se lee el dataset
path1="https://raw.githubusercontent.com/ANID-GITHUB/Historico-de-Proyectos-Adjudicados/master/BDH_HISTORICA.csv"
df=pd.read_csv(path1, sep=";")
# Out:
# c:\Users\mcifuentes\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# Limpieza de datos de proyectos ANID para la macrozona sur

# %%
#Creación de diccionarios para el reemplazo de ambiguedades instituciones mz sur
#Universidades con casa central en las regiones de la araucanía, los ríos y los lagos
#Universidad Austral de Chile
institucion_dict_UACH={"UNIVERSIDAD AUSTRAL":"UNIVERSIDAD AUSTRAL DE CHILE","UNIV. AUSTRAL DE CHILE":"UNIVERSIDAD AUSTRAL DE CHILE",\
    "Universidad Austral de Chile":"UNIVERSIDAD AUSTRAL DE CHILE","JARDIN INFANTIL UNIVERSIDAD AUSTRAL DE CHILE":"UNIVERSIDAD AUSTRAL DE CHILE"} 
#Universidad Católica de Temuco
institucion_dict_UCT={"UNIV.CATOLICA DE TEMUCO":"UNIVERSIDAD CATOLICA DE TEMUCO"} 
#Universidad de la Frontera
institucion_dict_UFRO={"UNIV.DE LA FRONTERA":"UNIVERSIDAD DE LA FRONTERA","U DE LA FRONTERA":"UNIVERSIDAD DE LA FRONTERA"} 
#Universidad de Los Lagos
institucion_dict_ULAGOS={"UNIV.DE LOS LAGOS":"UNIVERSIDAD DE LOS LAGOS","U DE LOS LAGOS":"UNIVERSIDAD DE LOS LAGOS"} 

#Otras instituciones asentadas en la macrozona
#Centros
#Centro de estudios científicos
institucion_dict_centros={"CENTRO DE ESTUDIOS CIENTIFICOS (CECS)":"CENTRO DE ESTUDIOS CIENTIFICOS"\
    ,"CENTRO DE GENOMICA NUTRICIONAL AGROACUICOLA (CGNA)":"CENTRO DE GENOMICA NUTRICIONAL AGROACUICOLA"\
        "CENT. GENOM. NUT. AGROACUICOLA - CGNA"
    ,"CENT. GENOM. NUT. AGROACUICOLA - CGNA":"CENTRO DE GENOMICA NUTRICIONAL AGROACUICOLA",\
    "CGNA":"CENTRO DE GENOMICA NUTRICIONAL AGROACUICOLA"} 

#Corrección de valores
df.replace({"INSTITUCION_PRINCIPAL": institucion_dict_UACH},inplace=True)
df.replace({"INSTITUCION_PRINCIPAL": institucion_dict_UCT},inplace=True)
df.replace({"INSTITUCION_PRINCIPAL": institucion_dict_UFRO},inplace=True)
df.replace({"INSTITUCION_PRINCIPAL": institucion_dict_ULAGOS},inplace=True)
df.replace({"INSTITUCION_PRINCIPAL": institucion_dict_centros},inplace=True)


#Corrección nombre de concursos

# %% [markdown]
# Se exporta en formato .csv a la carpeta

# %%
df.to_csv(r"C:\Users\mcifuentes\Google Drive\BBDD General\GitHub\Datos-CTCI-MZ-SUR\output\Proyectos Históricos Adjudicados - ANID MZ SUR CORREGIDO\pfinal.csv", index=False,sep=';',header=True)

# %% [markdown]
# Becas

# %%
#Se lee el dataset
path2="https://raw.githubusercontent.com/ANID-GITHUB/Becas/main/BDH_BECAS%20SCH.csv"
df2=pd.read_csv(path2, sep=";")
#Se exporta a la carpeta data
df2
# Out:
#        CODIGO_BECA      N    SUBDIRECCION PROGRAMA         TIPO_BECA  \
# 0         21170137    414  CAPITAL HUMANO    PFCHA           CONICYT
# 1         21190262    416  CAPITAL HUMANO    PFCHA           CONICYT
# 2         21200040    418  CAPITAL HUMANO    PFCHA           CONICYT
# 3         21201029    419  CAPITAL HUMANO    PFCHA           CONICYT
# 4         21202267    420  CAPITAL HUMANO    PFCHA           CONICYT
# ...            ...    ...             ...      ...               ...
# 16068     50230136  16069  CAPITAL HUMANO    PFCHA  CONICYT NACIONAL
# 16069     50230137  16070  CAPITAL HUMANO    PFCHA  CONICYT NACIONAL
# 16070     50230138  16071  CAPITAL HUMANO    PFCHA  CONICYT NACIONAL
# 16071     50230141  16072  CAPITAL HUMANO    PFCHA  CONICYT NACIONAL
# 16072     50230142  16073  CAPITAL HUMANO    PFCHA  CONICYT NACIONAL
#
#       NIVEL_BECA                           TIPO_PROGRAMA  \
# 0      DOCTORADO                               DOCTORADO
# ...

# %%
df2.to_csv(r"C:\Users\mcifuentes\Google Drive\BBDD General\GitHub\Datos-CTCI-MZ-SUR\output\Becas Históricos Adjudicados - ANID MZ SUR CORREGIDO\bfinal.csv", index=False,sep=';',header=True)

# %% [markdown]
# ##CORFO

# %%
url = "https://datainnovacion.cl/api/v1/proyectos"
payload = {"codigo": "19CV-12345"}
files = []
headers = {
        'Authorization': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJodHRwczpcL1wvZGF0YUlubm92YXRpb24uY2wiLCJuYW1lIjoicHVibGljIGFwaUtleSJ9.Ofu3LI0z8uCNYTbZyXd9BeY0sWIDt2NzUBwnHxTtdsA'
    }
response = requests.request("GET",url,headers=headers, data=payload, files=files)
df7 = pd.DataFrame.from_dict(response.json())

# %%
#Se establece las condiciones de filtro según el mapa de evaluaciones de MinCiencia
#condicion=(df7['instrumento']=='Consorcios Tecnológicos Para La Innovación') |\
#          (df7['instrumento']=='Proyectos De Fortalecimiento Y Formación De Capacidades Regionales Para La Innovación')|\
#          (df7['instrumento']=='Proyectos De Fortalecimiento Y Formación De Capacidades Regionales Para La Innovación')
          


#df7[condicion]

# %% [markdown]
# Se exporta en formato .csv a la carpeta

# %%
df7.to_csv(r"C:\Users\mcifuentes\Google Drive\BBDD General\GitHub\Datos-CTCI-MZ-SUR\output\Proyectos Data Innova CORFO\CORFOfinal.csv", index=False,sep=';',header=True)

# %% [markdown]
# ##MinCiencia

# %%
#Se lee el dataset

path2="https://api.observa.minciencia.gob.cl/api/datosabiertos/download/?handle=123456789/125914&filename=ProyectosCTCI.csv"
df2=pd.read_csv(path2, sep=";")
#Se exporta a la carpeta data
df2
# Out:
#            Código Agencia                         subdireccion  \
# 0      VIU21P0017    ANID  Investigación Aplicada e Innovación
# 1      VIU21P0051    ANID  Investigación Aplicada e Innovación
# 2      VIU21P0060    ANID  Investigación Aplicada e Innovación
# 3      VIU21P0064    ANID  Investigación Aplicada e Innovación
# 4      VIU21P0018    ANID  Investigación Aplicada e Innovación
# ...           ...     ...                                  ...
# 47813     PI-4581   Corfo                           Innovación
# 47814     PI-4586   Corfo                           Innovación
# 47815     PI-4647   Corfo                           Innovación
# 47816     PI-4678   Corfo                           Innovación
# 47817     PI-4688   Corfo                           Innovación
#
#            Instrumento                                           Concurso  \
# 0      VIU - Una Etapa  XI CONCURSO VALORIZACION DE LA INVESTIGACION E...
# ...

# %% [markdown]
# ##Fundación para la innovación agraria (FIA)
