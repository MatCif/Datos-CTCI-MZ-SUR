# %% [markdown]
# #Script para la obtención y limpieza de datos para el análisis CTCI de la macrozona sur SEREMI CTCI MZ SUR

# %% [markdown]
# #Sistema de Información de Educación Superior (SIES)
# de aquí extraeremos:
# -Matrículas
# -Oferta Académica
# -Dotación de académicos

# %% [markdown]
# Lo primero que se realiza es la obtención de datos de la página del Sistema de Información de Educación Superior (SIES) en matrículas históricas

# %%
import requests, zipfile, io

url = 'https://www.mifuturo.cl/wp-content/uploads/2022/07/OFICIAL_WEB_PROCESO_MAT_2007_AL_2022_24_06_2022_E-1.zip'
filename = 'OFICIAL_WEB_PROCESO_MAT_2007_AL_2022_24_06_2022_E.csv'

r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

#Se importan librerías importantes para el manejo de los dataframe
import numpy as np
import pandas as pd
# el submódulo pyplot contiene métodos que nos permitirán manipular los gráficos.
import matplotlib.pyplot as plt
df = pd.read_csv(filename, sep=';')
df

# %% [markdown]
# Limpieza de datos SIES

# %%
df.set_axis(['AÑO','TOTAL MATRICULADOS', 'MATRICULADOS MUJERES POR PROGRAMA', 'MATRICULADOS HOMBRES POR PROGRAMA', 'TOTAL MATRICULADOS PRIMER AÑO','MATRICULADOS MUJERES PRIMER AÑO', 'MATRICULADOS HOMBRES PRIMER AÑO',\
            'CLASIFICACIÓN INSTITUCIÓN NIVEL 1', 'CLASIFICACIÓN INSTITUCIÓN NIVEL 2', 'CLASIFICACIÓN INSTITUCIÓN NIVEL 3', 'CÓDIGO DE INSTITUCIÓN', 'NOMBRE INSTITUCIÓN', 'ACREDITACIÓN INSTITUCIONAL', 'REGIÓN',\
            'PROVINCIA','COMUNA', 'NOMBRE SEDE','NOMBRE CARRERA', 'ÁREA DEL CONOCIMIENTO','CINE-F 1997 ÁREA', 'CINE-F 1997 SUBAREA','ÁREA CARRERA GENÉRICA', 'CINE-F 2013 ÁREA','CINE-F 2013 SUBAREA',\
            'NIVEL GLOBAL','CARRERA CLASIFICACIÓN NIVEL 1','CARRERA CLASIFICACIÓN NIVEL 2','MODALIDAD','JORNADA','TIPO DE PLAN DE LA CARRERA', 'DURACIÓN ESTUDIO CARRERA', 'DURACIÓN TOTAL DE CARRERA',\
            'CÓDIGO CARRERA', 'ACREDITACIÓN CARRERA', 'TOTAL RANGO DE EDAD','RANGO DE EDAD 15 A 19 AÑOS', 'RANGO DE EDAD 20 A 24 AÑOS','RANGO DE EDAD 25 A 29 AÑOS', 'RANGO DE EDAD 30 A 34 AÑOS',\
            'RANGO DE EDAD 35 A 39 AÑOS','RANGO DE EDAD 40 Y MÁS AÑOS','RANGO DE EDAD SIN INFORMACIÓN', 'PROMEDIO EDAD CARRERA', 'PROMEDIO EDAD MUJER', 'PROMEDIO EDAD HOMBRE', 'TES MUNICIPAL',\
            'TES PARTICULAR SUBVENCIONADO', 'TES PARTICULAR PAGADO', 'TES CORP. DE ADMINISTRACIÓN DELEGADA', 'TES SERVICIO LOCAL EDUCACION', 'TOTAL TES','% COBERTURA TES', 'TIPO ESTABLECIMIENTO HC',\
            'TIPO ESTABLECIMIENTO TP','CLAS_EST ADULTO', 'CLAS_EST JOVEN'],axis=1,inplace=True)


#Cambiar de string a integer año
df2=df['AÑO'].replace({'MAT_':''},regex=True)
df['AÑO']=df2.astype(int)
df.dtypes

# %%
import requests
import pandas as pd
url = "https://datainnovacion.cl/api/v1/proyectos"
payload = {"codigo": "19CV-12345"}
files = []
headers = {
        'Authorization': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJodHRwczpcL1wvZGF0YUlubm92YXRpb24uY2wiLCJuYW1lIjoicHVibGljIGFwaUtleSJ9.Ofu3LI0z8uCNYTbZyXd9BeY0sWIDt2NzUBwnHxTtdsA'
    }
response = requests.request("GET",url,headers=headers, data=payload, files=files)
print(response.text)
df7 = pd.DataFrame.from_dict(response.json())

# %%
df7

# %%
df7.to_clipboard()

# %%
#Se establece las condiciones de filtro según el mapa de evaluaciones de MinCiencia
condicion=(df7['instrumento']=='Consorcios Tecnológicos Para La Innovación') |\
          (df7['instrumento']=='Proyectos De Fortalecimiento Y Formación De Capacidades Regionales Para La Innovación')|\
          (df7['instrumento']=='Proyectos De Fortalecimiento Y Formación De Capacidades Regionales Para La Innovación')
          


df7[condicion]

# %%
import requests
from bs4 import BeautifulSoup
 
 
url = 'https://www.mifuturo.cl/bases-de-datos-de-matriculados/'
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')
 
urls = []
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# https://educacionsuperior.mineduc.cl/
# https://www.mifuturo.cl
# https://www.mifuturo.cl
# https://www.mifuturo.cl/preguntas-frecuentes
# https://www.mifuturo.cl/mapa-del-sitio
# #iniciosesion
# #mdlregistro
# //www.mifuturo.cl
# #
# https://www.mifuturo.cl/por-que-ingresar/
# https://www.mifuturo.cl/la-importancia-de-la-calidad/
# https://www.mifuturo.cl/proyectandose-al-futuro/
# https://www.mifuturo.cl/como-ingresar/
# #
# https://www.mifuturo.cl/servicio-de-informacion-de-educacion-superior/
# https://www.mifuturo.cl/instituciones-de-educacion-superior-en-chile/
# https://www.mifuturo.cl/informes-de-matricula/
# https://www.mifuturo.cl/informes-de-titulacion/
# #
# https://www.mifuturo.cl/tipos-de-institucion/
# https://www.mifuturo.cl/buscador-de-carreras/
# https://www.mifuturo.cl/buscador-de-instituciones/
# https://www.mifuturo.cl/universidades/
# https://www.mifuturo.cl/institutos-profesionales-ip/
# https://www.mifuturo.cl/centros-de-formacion-tecnica-cft/
# #
# https://www.mifuturo.cl/alternativas-para-financiar-tu-carrera/
# https://www.mifuturo.cl/como-postular-a-beneficios/
# https://www.mifuturo.cl/arancel-de-la-carrera/
# #
# https://www.mifuturo.cl/indicadores-de-empleabilidad-e-ingresos/
# https://www.mifuturo.cl/buscador-de-estadisticas-por-carrera/
# https://www.mifuturo.cl/buscador-de-empleabilidad-e-ingresos/
# https://www.mifuturo.cl/wp-content/uploads/2022/07/OFICIAL-GLOSARIO-DE-LA-MATRICULA-WEB_E.pdf
# //www.mifuturo.cl
# #
# #recuperarpass
# #
# #
#
# #
# #iniciosesion
# #mdlregistro
# tel:+56 2 24066000
# tel:+56 2 24066000
# http://transparencia.mineduc.cl/
# http://transparencia.mineduc.cl/

# %% [markdown]
# #Agencia Nacional de Investigación (ANID)
# de aquí extraeremos:
# -Proyectos ANID Financiados
# -Becas adjudicadas

# %%
#Se lee el dataset
path1="https://raw.githubusercontent.com/ANID-GITHUB/Historico-de-Proyectos-Adjudicados/master/BDH_Proyectos.csv"
df=pd.read_csv(path1, sep=";")
#Se exporta a la carpeta data
df
# Out:
#       CODIGO_PROYECTO      N                SUBDIRECCION  PROGRAMA  \
# 0             1820005      1  PROYECTOS DE INVESTIGACION  FONDECYT
# 1             1820006      2  PROYECTOS DE INVESTIGACION  FONDECYT
# 2             1820009      3  PROYECTOS DE INVESTIGACION  FONDECYT
# 3             1820010      4  PROYECTOS DE INVESTIGACION  FONDECYT
# 4             1820015      5  PROYECTOS DE INVESTIGACION  FONDECYT
# ...               ...    ...                         ...       ...
# 40374       SUC220131  40385      INVESTIGACION APLICADA    FONDEF
# 40375       SUC220135  40386      INVESTIGACION APLICADA    FONDEF
# 40376       SUC220141  40387      INVESTIGACION APLICADA    FONDEF
# 40377       SUC220143  40388      INVESTIGACION APLICADA    FONDEF
# 40378       SUC220144  40389      INVESTIGACION APLICADA    FONDEF
#
#            INSTRUMENTO                     NOMBRE_CONCURSO  AGNO_CONCURSO  \
# 0              REGULAR      CONCURSO NACIONAL REGULAR 1982           1982
# 1              REGULAR      CONCURSO NACIONAL REGULAR 1982           1982
# 2              REGULAR      CONCURSO NACIONAL REGULAR 1982           1982
# 3              REGULAR      CONCURSO NACIONAL REGULAR 1982           1982
# 4              REGULAR      CONCURSO NACIONAL REGULAR 1982           1982
# ...                ...                                 ...            ...
# 40374  STARTUP CIENCIA  CONCURSO STARTUP CIENCIA, AÑO 2022           2022
# 40375  STARTUP CIENCIA  CONCURSO STARTUP CIENCIA, AÑO 2022           2022
# 40376  STARTUP CIENCIA  CONCURSO STARTUP CIENCIA, AÑO 2022           2022
# 40377  STARTUP CIENCIA  CONCURSO STARTUP CIENCIA, AÑO 2022           2022
# 40378  STARTUP CIENCIA  CONCURSO STARTUP CIENCIA, AÑO 2022           2022
#
#        AGNO_FALLO                                    NOMBRE_PROYECTO  \
# 0            1982  SORCION Y DESORCION DE METALES PESADOS EN SUELOS.
# 1            1982  ESTIMACION DEL IMPACTO DEL SANEAMIENTO BASICO ...
# 2            1982        EFECTOS NO IDEALES EN UN PLASMA CILINDRICO.
# 3            1982  ESTUDIO SOBRE LA CONCIENCIA DE LA REALIDAD POL...
# 4            1982  ESTUDIO DE INTERACCIONES ENTRE "BIOELECTROQUIM...
# ...           ...                                                ...
# 40374        2022  ALGAFEX: BIODESINFECTANTE NATURAL A PARTIR DE ...
# 40375        2022  LIGNIUM ENERGY, DESARROLLO DE UNA PLANTA PARA ...
# 40376        2022  RESIXTEC. DISEÑO Y CREACION DE DISPOSITIVOS DE...
# 40377        2022  OBTENCION DE INGREDIENTES FUNCIONALES A NIVEL ...
# 40378        2022                    ASESOR VIRTUAL DE MANTENIMIENTO
#
#                             AREA_OCDE  ...   GRUPO_DE_EVALUACION  \
# 0                  CIENCIAS NATURALES  ...               QUIMICA
# 1      CIENCIAS MEDICAS Y DE LA SALUD  ...            MEDICINA 1
# 2                  CIENCIAS NATURALES  ...  FISICA TEORICA Y EXP
# 3                         HUMANIDADES  ...              HISTORIA
# 4                  CIENCIAS NATURALES  ...               QUIMICA
# ...                               ...  ...                   ...
# 40374              CIENCIAS AGRICOLAS  ...             NO APLICA
# 40375         INGENIERIA Y TECNOLOGIA  ...             NO APLICA
# 40376         INGENIERIA Y TECNOLOGIA  ...             NO APLICA
# 40377              CIENCIAS NATURALES  ...             NO APLICA
# 40378         INGENIERIA Y TECNOLOGIA  ...             NO APLICA
#
#       DURACION_MESES TIPO_BENEFICIARIO                 NOMBRE_RESPONSABLE  \
# 0                 12   PERSONA NATURAL    EDUARDO VICTOR SCHALSCHA BECKER
# 1                 12   PERSONA NATURAL  ANGEL CLAUDIO FLISFISCH FERNANDEZ
# 2                 12   PERSONA NATURAL             LUIS GOMBEROFF JAIKLES
# 3                 12   PERSONA NATURAL     PEDRO CRISTIAN GAZMURI RIVEROS
# 4                 12   PERSONA NATURAL        JUAN ARTURO SQUELLA SERRANO
# ...              ...               ...                                ...
# 40374             12  PERSONA JURIDICA           NATHALY RUIZ-TAGLE MOENA
# 40375             12  PERSONA JURIDICA           AGUSTIN DOMINGUEZ VALDES
# 40376             12  PERSONA JURIDICA               CLAUDIO PEREZ MENDEZ
# 40377             12  PERSONA JURIDICA           MOISES PULGAR SAN MARTIN
# 40378             12  PERSONA JURIDICA                 FELIPE BUESO BRAVO
#
#          SEXO                              INSTITUCION_PRINCIPAL  \
# 0      HOMBRE                               UNIVERSIDAD DE CHILE
# 1      HOMBRE  FACULTAD LATINOAMERICANA DE CIENCIAS SOCIALES ...
# 2      HOMBRE                               UNIVERSIDAD DE CHILE
# 3      HOMBRE                                         PARTICULAR
# 4      HOMBRE                               UNIVERSIDAD DE CHILE
# ...       ...                                                ...
# 40374   MUJER                          GREEN FOCUS SOLUTIONS SPA
# 40375  HOMBRE            SOCIEDAD EXPLOTADORA LIGNIUM ENERGY SPA
# 40376  HOMBRE                                       RESIXTEC SPA
# 40377  HOMBRE                                   KIMUN BIOTEC SPA
# 40378  HOMBRE                                             JAKSOL
#
#       MACROZONA_MINCIENCIA   REGION_EJECUCION MONTO_ADJUDICADO..M.. NOTA_MONTO
# 0                       RM  13. METROPOLITANA                   300        NaN
# 1                       RM  13. METROPOLITANA                   130        NaN
# 2                       RM  13. METROPOLITANA                   506        NaN
# 3                       RM  13. METROPOLITANA                   335        NaN
# 4                       RM  13. METROPOLITANA                   260        NaN
# ...                    ...                ...                   ...        ...
# 40374           CENTRO SUR         08. BIOBIO                120000        NaN
# 40375                   RM  13. METROPOLITANA                118113        NaN
# 40376           CENTRO SUR          07. MAULE                119570        NaN
# 40377           CENTRO SUR          16. ÑUBLE                120000        NaN
# 40378                   RM  13. METROPOLITANA                120000        NaN
#
# [40379 rows x 21 columns]

# %% [markdown]
# Limpieza de datos ANID

# %%
#Creación de diccionarios para el reemplazo de ambiguedades instituciones mz sur
#Universidades con casa central en las regiones de la araucanía, los ríos y los lagos
#Universidad Austral de Chile
institucion_dict_UACH={"UNIVERSIDAD AUSTRAL":"UNIVERSIDAD AUSTRAL DE CHILE","UNIV. AUSTRAL DE CHILE":"UNIVERSIDAD AUSTRAL DE CHILE",\
    "Universidad Austral de Chile":"UNIVERSIDAD AUSTRAL DE CHILE","JARDIN INFANTIL UNIVERSIDAD AUSTRAL DE CHILE":"UNIVERSIDAD AUSTRAL DE CHILE"} 
#Universidad Católica de Temuco
institucion_dict_UCT={"UNIV.CATOLICA DE TEMUCO":"UNIVERSIDAD CATOLICA DE TEMUCO"} 
#Universidad de la Frontera
institucion_dict_UFRO={"UNIV.DE LA FRONTERA":"UNIVERSIDAD DE LA FRONTERA","U DE LA FRONTERA":"UNIVERSIDAD DE LA FRONTERA"} 
#Universidad de Los Lagos
institucion_dict_ULAGOS={"UNIV.DE LOS LAGOS":"UNIVERSIDAD DE LOS LAGOS","U DE LOS LAGOS":"UNIVERSIDAD DE LOS LAGOS"} 

#Otras instituciones asentadas en la macrozona
#Centros
#Centro de estudios científicos
institucion_dict_centros={"CENTRO DE ESTUDIOS CIENTIFICOS (CECS)":"CENTRO DE ESTUDIOS CIENTIFICOS"\
    ,"CENTRO DE GENOMICA NUTRICIONAL AGROACUICOLA (CGNA)":"CENTRO DE GENOMICA NUTRICIONAL AGROACUICOLA"\
        "CENT. GENOM. NUT. AGROACUICOLA - CGNA"
    ,"CENT. GENOM. NUT. AGROACUICOLA - CGNA":"CENTRO DE GENOMICA NUTRICIONAL AGROACUICOLA",\
    "CGNA":"CENTRO DE GENOMICA NUTRICIONAL AGROACUICOLA"} 

#Corrección de valores
df.replace({"INSTITUCION_PRINCIPAL": institucion_dict_UACH},inplace=True)
df.replace({"INSTITUCION_PRINCIPAL": institucion_dict_UCT},inplace=True)
df.replace({"INSTITUCION_PRINCIPAL": institucion_dict_UFRO},inplace=True)
df.replace({"INSTITUCION_PRINCIPAL": institucion_dict_ULAGOS},inplace=True)
df.replace({"INSTITUCION_PRINCIPAL": institucion_dict_centros},inplace=True)


df
# Out:
#       CODIGO_PROYECTO      N                SUBDIRECCION  PROGRAMA  \
# 0             1820005      1  PROYECTOS DE INVESTIGACION  FONDECYT
# 1             1820006      2  PROYECTOS DE INVESTIGACION  FONDECYT
# 2             1820009      3  PROYECTOS DE INVESTIGACION  FONDECYT
# 3             1820010      4  PROYECTOS DE INVESTIGACION  FONDECYT
# 4             1820015      5  PROYECTOS DE INVESTIGACION  FONDECYT
# ...               ...    ...                         ...       ...
# 40374       SUC220131  40385      INVESTIGACION APLICADA    FONDEF
# 40375       SUC220135  40386      INVESTIGACION APLICADA    FONDEF
# 40376       SUC220141  40387      INVESTIGACION APLICADA    FONDEF
# 40377       SUC220143  40388      INVESTIGACION APLICADA    FONDEF
# 40378       SUC220144  40389      INVESTIGACION APLICADA    FONDEF
#
#            INSTRUMENTO                     NOMBRE_CONCURSO  AGNO_CONCURSO  \
# 0              REGULAR      CONCURSO NACIONAL REGULAR 1982           1982
# 1              REGULAR      CONCURSO NACIONAL REGULAR 1982           1982
# 2              REGULAR      CONCURSO NACIONAL REGULAR 1982           1982
# 3              REGULAR      CONCURSO NACIONAL REGULAR 1982           1982
# 4              REGULAR      CONCURSO NACIONAL REGULAR 1982           1982
# ...                ...                                 ...            ...
# 40374  STARTUP CIENCIA  CONCURSO STARTUP CIENCIA, AÑO 2022           2022
# 40375  STARTUP CIENCIA  CONCURSO STARTUP CIENCIA, AÑO 2022           2022
# 40376  STARTUP CIENCIA  CONCURSO STARTUP CIENCIA, AÑO 2022           2022
# 40377  STARTUP CIENCIA  CONCURSO STARTUP CIENCIA, AÑO 2022           2022
# 40378  STARTUP CIENCIA  CONCURSO STARTUP CIENCIA, AÑO 2022           2022
#
#        AGNO_FALLO                                    NOMBRE_PROYECTO  \
# 0            1982  SORCION Y DESORCION DE METALES PESADOS EN SUELOS.
# 1            1982  ESTIMACION DEL IMPACTO DEL SANEAMIENTO BASICO ...
# 2            1982        EFECTOS NO IDEALES EN UN PLASMA CILINDRICO.
# 3            1982  ESTUDIO SOBRE LA CONCIENCIA DE LA REALIDAD POL...
# 4            1982  ESTUDIO DE INTERACCIONES ENTRE "BIOELECTROQUIM...
# ...           ...                                                ...
# 40374        2022  ALGAFEX: BIODESINFECTANTE NATURAL A PARTIR DE ...
# 40375        2022  LIGNIUM ENERGY, DESARROLLO DE UNA PLANTA PARA ...
# 40376        2022  RESIXTEC. DISEÑO Y CREACION DE DISPOSITIVOS DE...
# 40377        2022  OBTENCION DE INGREDIENTES FUNCIONALES A NIVEL ...
# 40378        2022                    ASESOR VIRTUAL DE MANTENIMIENTO
#
#                             AREA_OCDE  ...   GRUPO_DE_EVALUACION  \
# 0                  CIENCIAS NATURALES  ...               QUIMICA
# 1      CIENCIAS MEDICAS Y DE LA SALUD  ...            MEDICINA 1
# 2                  CIENCIAS NATURALES  ...  FISICA TEORICA Y EXP
# 3                         HUMANIDADES  ...              HISTORIA
# 4                  CIENCIAS NATURALES  ...               QUIMICA
# ...                               ...  ...                   ...
# 40374              CIENCIAS AGRICOLAS  ...             NO APLICA
# 40375         INGENIERIA Y TECNOLOGIA  ...             NO APLICA
# 40376         INGENIERIA Y TECNOLOGIA  ...             NO APLICA
# 40377              CIENCIAS NATURALES  ...             NO APLICA
# 40378         INGENIERIA Y TECNOLOGIA  ...             NO APLICA
#
#       DURACION_MESES TIPO_BENEFICIARIO                 NOMBRE_RESPONSABLE  \
# 0                 12   PERSONA NATURAL    EDUARDO VICTOR SCHALSCHA BECKER
# 1                 12   PERSONA NATURAL  ANGEL CLAUDIO FLISFISCH FERNANDEZ
# 2                 12   PERSONA NATURAL             LUIS GOMBEROFF JAIKLES
# 3                 12   PERSONA NATURAL     PEDRO CRISTIAN GAZMURI RIVEROS
# 4                 12   PERSONA NATURAL        JUAN ARTURO SQUELLA SERRANO
# ...              ...               ...                                ...
# 40374             12  PERSONA JURIDICA           NATHALY RUIZ-TAGLE MOENA
# 40375             12  PERSONA JURIDICA           AGUSTIN DOMINGUEZ VALDES
# 40376             12  PERSONA JURIDICA               CLAUDIO PEREZ MENDEZ
# 40377             12  PERSONA JURIDICA           MOISES PULGAR SAN MARTIN
# 40378             12  PERSONA JURIDICA                 FELIPE BUESO BRAVO
#
#          SEXO                              INSTITUCION_PRINCIPAL  \
# 0      HOMBRE                               UNIVERSIDAD DE CHILE
# 1      HOMBRE  FACULTAD LATINOAMERICANA DE CIENCIAS SOCIALES ...
# 2      HOMBRE                               UNIVERSIDAD DE CHILE
# 3      HOMBRE                                         PARTICULAR
# 4      HOMBRE                               UNIVERSIDAD DE CHILE
# ...       ...                                                ...
# 40374   MUJER                          GREEN FOCUS SOLUTIONS SPA
# 40375  HOMBRE            SOCIEDAD EXPLOTADORA LIGNIUM ENERGY SPA
# 40376  HOMBRE                                       RESIXTEC SPA
# 40377  HOMBRE                                   KIMUN BIOTEC SPA
# 40378  HOMBRE                                             JAKSOL
#
#       MACROZONA_MINCIENCIA   REGION_EJECUCION MONTO_ADJUDICADO..M.. NOTA_MONTO
# 0                       RM  13. METROPOLITANA                   300        NaN
# 1                       RM  13. METROPOLITANA                   130        NaN
# 2                       RM  13. METROPOLITANA                   506        NaN
# 3                       RM  13. METROPOLITANA                   335        NaN
# 4                       RM  13. METROPOLITANA                   260        NaN
# ...                    ...                ...                   ...        ...
# 40374           CENTRO SUR         08. BIOBIO                120000        NaN
# 40375                   RM  13. METROPOLITANA                118113        NaN
# 40376           CENTRO SUR          07. MAULE                119570        NaN
# 40377           CENTRO SUR          16. ÑUBLE                120000        NaN
# 40378                   RM  13. METROPOLITANA                120000        NaN
#
# [40379 rows x 21 columns]

# %%
#df.to_csv(r"C:\Users\mcifuentes\Google Drive\BBDD General\GitHub\Datos-CTCI-MZ-SUR\output\Proyectos Históricos Adjudicados - ANID MZ SUR CORREGIDO\pfinal.csv", index=False,sep=';',header=True)
